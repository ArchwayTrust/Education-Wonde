# %% [markdown]
# # Ingest schools
# Gets information about each available school including it's Wonde ID.

# %%
# %run _Config
# Out:
# StatementMeta(, a41d25c5-b869-4df5-850a-74bc0f9d80fd, -1, Finished, Available)

# %%
# %run _WondeStructs
# Out:
# StatementMeta(, a41d25c5-b869-4df5-850a-74bc0f9d80fd, -1, Finished, Available)

# %%
# %run _WondeAPI
# Out:
# StatementMeta(, a41d25c5-b869-4df5-850a-74bc0f9d80fd, -1, Finished, Available)

# %%
url = baseWondeUrl + "schools"

df = getWondeAPI(url, wondeHeaders, structWondeSchool)
# Out:
# StatementMeta(, a41d25c5-b869-4df5-850a-74bc0f9d80fd, 11, Finished, Available)

# %%
display(df)
# Out:
# StatementMeta(, a41d25c5-b869-4df5-850a-74bc0f9d80fd, 12, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 2daebbe8-bdde-4082-b158-3a30932972de)

# %%
dfFinal = (df.select(
            col("*"), 
            col("address.address_postcode"))
            .drop("address")
        )

display(dfFinal)
# Out:
# StatementMeta(, a41d25c5-b869-4df5-850a-74bc0f9d80fd, 14, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 27d9e515-c2c8-44ae-8f77-825903aae74a)

# %%
(dfFinal.write
    .mode("overwrite")
    .option("mergeSchema", "true")
    .format("delta")
    .save(BronzeBasePath + "/Schools")
    )
# Out:
# StatementMeta(, a41d25c5-b869-4df5-850a-74bc0f9d80fd, 16, Finished, Available)
